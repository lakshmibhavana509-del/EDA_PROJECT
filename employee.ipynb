# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_excel("/content/employee dataset.xlsx")
df.head()#shows first 5 rows
# Out:
#    Employee_ID   Name        Age Department Salary Experience
# 0          101   Ravi         25         IT  35000          2
# 1          102   Sita         28         HR  40000          4
# 2          103  Kiran  (Missing)         IT  45000          3
# 3          104    Anu         26    Finance  38000          2
# 4          105    Ram         29         IT  50000          5

# %%
df.tail()# shows last 5 rows
# Out:
#     Employee_ID   Name Age Department Salary Experience
# 20          121   Ravi  25         IT  35000          2
# 21          122   Sita  28         HR  40000          4
# 22          123  Kiran  24         IT  45000          3
# 23          124    Anu  26    Finance  38000          2
# 24          125    Ram  29         IT  50000          5

# %%
df.shape# count of

# %%
df.info()#shows cols,datatypes,nonnull values

# %%
df.isnull().sum()

# %%
df["Employee_ID"].unique()

# %%
df["Name"].unique()

# %%
df["Age"].unique()

# %%
df["Department"].unique()

# %%
df["Salary"].unique()

# %%
df["Experience"].unique()

# %%
#Handling Missing Vales
import pandas as pd
df=pd.read_excel("/content/employee dataset.xlsx")

missing_values = ["(Missing)", "Missing", "NA", "N/A", "Null", "NULL", ""]

df.replace(missing_values, pd.NA, inplace=True)

print(df.isnull().sum())
# Out:
# Employee_ID    0
# Name           0
# Age            2
# Department     0
# Salary         1
# Experience     1
# dtype: int64

# %%
# missing values handled by mean imputation
df["Age"]=df["Age"].fillna(df["Age"].mean())
df["Salary"]=df["Salary"].fillna(df["Salary"].mean())
df["Experience"]=df["Experience"].fillna(df["Experience"].mean())
df.isnull().sum()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for col in ["Age", "Salary", "Experience"]:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col} Outliers: {len(outliers)}")
# Out:
# Age Outliers: 2
# Salary Outliers: 1
# Experience Outliers: 2

# %%
df.describe()

# %%
import matplotlib.pyplot as plt
df['Department'].value_counts().plot(kind='bar')
plt.title("Employees by Department")
plt.show()

# %%
df['Department'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Department Distribution")
plt.ylabel('')
plt.show()

# %%
import matplotlib.pyplot as plt
salary = pd.to_numeric(df['Salary'], errors='coerce')
plt.hist(salary.dropna())
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df['Experience'] = pd.to_numeric(df['Experience'], errors='coerce')
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
df2 = df[['Experience','Salary']].dropna()
plt.scatter(df2['Experience'], df2['Salary'])
plt.title("Experience vs Salary")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(df['Employee_ID'], df['Salary'])
plt.title('Employee Salary Trend')
plt.xlabel('Employee ID')
plt.ylabel('Salary')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(y=df['Salary'])
plt.title('Salary Box Plot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.violinplot(y=df['Salary'])
plt.title('Salary Violin Plot')
plt.show()
